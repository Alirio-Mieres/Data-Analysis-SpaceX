# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data/spacex_web_scraped.csv')

# %%
df.head()
# Out:
#    Flight No. Launch site                               Payload Payload mass  \
# 0           1       CCAFS  Dragon Spacecraft Qualification Unit            0
# 1           2       CCAFS                                Dragon            0
# 2           3       CCAFS                                Dragon       525 kg
# 3           4       CCAFS                          SpaceX CRS-1     4,700 kg
# 4           5       CCAFS                          SpaceX CRS-2     4,877 kg
#
#   Orbit Customer Launch outcome   Version Booster Booster landing        Date  \
# 0   LEO   SpaceX        Failure  F9 v1.07B0003.18         Failure  2010-06-04
# 1   LEO     NASA        Failure  F9 v1.07B0004.18         Failure  2010-12-08
# 2   LEO     NASA     No attempt  F9 v1.07B0005.18    No attempt\n  2012-05-22
# 3   LEO     NASA     No attempt  F9 v1.07B0006.18      No attempt  2012-10-08
# 4   LEO     NASA     No attempt  F9 v1.07B0007.18    No attempt\n  2013-03-01
#
#     Time  Class
# 0  18:45      0
# 1  15:43      0
# 2  07:44      0
# 3  00:35      0
# 4  15:10      0

# %% [markdown]
# ## Relationship between Flight Number and Launch Site

# %%
sns.catplot(x="Flight No.", y="Launch site", hue="Class", data=df, aspect=5)
plt.xlabel("Flight Number",fontsize=20)
plt.ylabel("Launch Site",fontsize=20)
plt.show()

# %% [markdown]
# ## Visualize the launch success yearly trend

# %%
year = []
def Extract_year():
    for i in df["Date"]:
        year.append(i.split("-")[0])
    return year
Extract_year()
df['Date'] = year
df.head()
# Out:
#    Flight No. Launch site                               Payload Payload mass  \
# 0           1       CCAFS  Dragon Spacecraft Qualification Unit            0
# 1           2       CCAFS                                Dragon            0
# 2           3       CCAFS                                Dragon       525 kg
# 3           4       CCAFS                          SpaceX CRS-1     4,700 kg
# 4           5       CCAFS                          SpaceX CRS-2     4,877 kg
#
#   Orbit Customer Launch outcome   Version Booster Booster landing  Date  \
# 0   LEO   SpaceX        Failure  F9 v1.07B0003.18         Failure  2010
# 1   LEO     NASA        Failure  F9 v1.07B0004.18         Failure  2010
# 2   LEO     NASA     No attempt  F9 v1.07B0005.18    No attempt\n  2012
# 3   LEO     NASA     No attempt  F9 v1.07B0006.18      No attempt  2012
# 4   LEO     NASA     No attempt  F9 v1.07B0007.18    No attempt\n  2013
#
#     Time  Class
# 0  18:45      0
# 1  15:43      0
# 2  07:44      0
# 3  00:35      0
# 4  15:10      0

# %%
sns.lineplot(data=df, x="Date", y="Class")
plt.xlabel("Year")
plt.ylabel("Success Rate")
plt.show()
